# %% [markdown]
# <p class='notebook_header'><b>CS 309 - Robot Learning</b></p>
# <p class='notebook_header'>Homework 1</p>
# <hr class='separate' />

# %% [markdown]
# <p class='section_header'><b>Part 1: Linear Algebra</b></p>

# %% [markdown]
# Implement the following matrix/vector functions using NumPy operations.
#
# If the function's operation isn't possible for matrix or vector inputs, return None.

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
def add(a, b):
    return np.add(a, b)

def subtract(a, b):
    return np.subtract(a,b)

def multiply(a, b):
    return np.multiply(a,b)

def divide(a, b):
    return np.divide(a,b)

def transpose(a):
    return np.a.T

def twonorm(a):
    return np.norm(a)

# %% [markdown]
# <p>Using your code from above, solve the following equations. If an operation isn't possible, put None or comment with "Not Possible".</p>

# %% [markdown]
# $$
# u = \begin{bmatrix} 2 \\ 3 \\ 9 \end{bmatrix}, \:
# v = \begin{bmatrix} -2 \\ 1 \\ 8 \end{bmatrix}
# $$

# %%
u = np.array([
    [2],
    [3],
    [9]
])

v = u = np.array([
    [-2],
    [1],
    [8]
])

# %% [markdown]
# $$ u + v = \begin{bmatrix} ? \end{bmatrix} $$
#
# $$ u - v = \begin{bmatrix} ? \end{bmatrix} $$
#
# $$ u * v = \begin{bmatrix} ? \end{bmatrix} $$
#
# $$ u \div v = \begin{bmatrix} ? \end{bmatrix} $$

# %%
# YOUR CODE HERE

u_plus_v = add(u, v)

u_minus_v = subtract(u, v)

u_mult_v = multiply(u, v)

u_div_v = divide(u, v)

# %% [markdown]
# $$ u^{\;T} * v = \; ? $$
#
# $$ u * v^{\;T} = \begin{bmatrix} ? \end{bmatrix} $$
#
# $$ u^{\;T} * u = \; ? $$
#
# $$ \left \| u \right \|_{2}^{2} = ? $$

# %%
# YOUR CODE HERE

u_transpose_v = np.dot(transpose(u), v)

u_v_tranpose = np.dot(u, tranpose(v))

u_tranpose_u = np.dot(tranpose(u), u)

two_norm_u = twonorm(u)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-6359e215c672> in <module>
#       1 # YOUR CODE HERE
#       2
# ----> 3 u_transpose_v = np.dot(transpose(u), v)
#       4
#       5 u_v_tranpose = np.dot(u, tranpose(v))
#
# <ipython-input-56-f0e5997cc6fe> in transpose(a)
#      12
#      13 def transpose(a):
# ---> 14     return np.a.T
#      15
#      16 def twonorm(a):
#
# ~\miniconda3\envs\fri_rl\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     213             else:
#     214                 raise AttributeError("module {!r} has no attribute "
# --> 215                                      "{!r}".format(__name__, attr))
#     216
#     217         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'a'

# %% [markdown]
# <hr class='light-separate' />

# %% [markdown]
# $$
# A = \begin{bmatrix} 1 & 6 & 5\\ 0 & -4 & -1\\ 7 & 2 & 3 \end{bmatrix}, \:
# B = \begin{bmatrix} 3 & 1 & 1\\ 4 & -1 & 7\\ 7 & 0 & 0 \end{bmatrix}
# $$

# %% [markdown]
# $$ A + B = \begin{bmatrix} ? \end{bmatrix} $$
#
# $$ A - B = \begin{bmatrix} ? \end{bmatrix} $$
#
# $$ A * B = \begin{bmatrix} ? \end{bmatrix} $$
#
# $$ A \div B = \begin{bmatrix} ? \end{bmatrix} $$

# %%
# YOUR CODE HERE

a = np.array([[1, 0, 7], [6, -4, 2], [5, -1, 3]])
b = np.array([[3, 4, 7], [1, -1, 0], [1, 7, 0]])

a_plus_b = add(a, b)

a_minus_b = subtract(a, b)

a_mult_b = multiply(a, b)

a_div_b = divide(a, b)
# Out:
# C:\Users\alari\miniconda3\envs\fri_rl\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# <hr class='light-separate' />

# %% [markdown]
# $$
# C = \begin{bmatrix} 5 & 1 \\ -1 & 7 \\ 3 & 0 \end{bmatrix}
# $$

# %%
c = np.array([[5, 1],
              [-1, 7],
              [3, 0]])

# %% [markdown]
# Right Pseudo Inverse of C:
# $$
# \begin{bmatrix} ? \end{bmatrix}
# $$
#
# Left Pseudo Inverse of C:
# $$
# \begin{bmatrix} ? \end{bmatrix}
# $$

# %%
# YOUR CODE HERE
right_pinv = np.linalg.pinv(c.T)

left_pinv = np.linalg.pinv(c)

# %% [markdown]
# <hr class='separate' />

# %% [markdown]
# <p class='section_header'><b>Part 2: Regression</b></p>

# %% [markdown]
# **Write** the equation for Ordinary Least Squares below.
#
# **(TODO: Write Here)** (x^T * x)^-1 * x^T * y = theta

# %% [markdown]
# **Explain** Ordinary Least Squares in terms of what it optimizes.
#
# **(TODO: Write Here)** One uses OLS in order to optimize the best possible straight line given a set of data points. OLS minimizes the errors by penalizing the points that are too fair away from the mean data point.

# %%
# Don't change this cell!
# Load in the data about the study on students
train = np.loadtxt('train.csv', delimiter=',')
x_0, x_1, x_2, y = train.T
X_train = np.array([x_0, x_1, x_2]).T
Y_train = np.expand_dims(y, 1)

test = np.loadtxt('test.csv', delimiter=',')
x_0, x_1, x_2, y = test.T
X_test = np.array([x_0, x_1, x_2]).T
Y_test = np.expand_dims(y, 1)

# %% [markdown]
# There was an imaginary study done on 101 students at Crest University. The study surveyed students for the amount they have spent on electronics, books, pencils, and foods.

# %% [markdown]
# Given that the **amount students spend on electronics ($Y$)** is linearly related to the **amount they spend on books ($ X_{0} $), pencils ($ X_{1}$)**, and **food ($ X_{2}$)**,
# **implement** the Ordinary Least Squares method to model this regression problem.
#
# The data is read in from the previous cell code. **X_train** has the input features, while **Y_train** has corresponding target outputs.
#
# After finding a solution, try to measure the error between your predictions and the ground truth.

# %%
# TODO: Create code for OLS here. DO NOT use any other libraries in your first implementation.
# TODO: Plot your regression line over the input points.

def OLS(X, y):
    return np.linalg.pinv(X.T) * y

# TODO: check against training data
theta = OLS(X_train,Y_train)
thetaTest = OLS(X_test, Y_test)

# TODO: test your model on testing data
def numpy_plot():
    plt.plot(theta)
    plt.plot(thetaTest)
    plt.show()
    
numpy_plot()

# %% [markdown]
# **Explain** what collinearity is.
#
# **(TODO: Write Here)** Collinearity is when a feature variable is highly correlated with another feature variable.

# %% [markdown]
# **Write** the equation for Ridge Regression below.
#
# **(TODO: Write Here)** (X^T * X + alpha * I)^-1 * X * y

# %% [markdown]
# **Explain** what the purpose ridge regression and its advantages and disadvantages over OLS.
#
# **(TODO: Write Here)** The purpose of ridge regression is to analyze multiple regression data that have collinearity. An advantage ridge regression has over OLS is ridge regression gives a bias to important features so the line of best fit matches more closely to those data points, compared to OLS which treats all data points equally. A disadvantage of ridge regression over OLS is the trade-off between variance and bias.

# %% [markdown]
# **Implement** your regression model with ridge regression below.

# %%
# TODO: Create code for Ridge Regression here. DO NOT use any other libraries
# TODO: Plot your regression line over the input points.

def RR(X, y, ridge=0.001):
    I = np.identity(3)
    return np.dot(np.dot(np.linalg.inv(np.dot(X.T, X) + ridge * I), X.T), y)

# TODO: check against training data
theta = RR(X_train,Y_train)
thetaTest = RR(X_test, Y_test)

# TODO: test your model on testing data
plt.plot(theta)
plt.plot(thetaTest)
plt.show()

# %% [markdown]
# **Explain** the differences ridge regression created for theta compared to OLS, and why these differences even existed. Also try different values for the ridge parameters and describe how they effect your results.
#
# **(TODO: Write here)** The OLS model seems to oscillate at y = 0, while the ridge regression model seems to be in a V shape, rapidly decreasing to x = 1 and then increasing after x = 1. These differences exist because the OLS model overfits and tries to match all of the data points, while the ridge regression model gives a bias towards some data points so it doesn't have to fit all data points. The closer the ridge parameter gets to 0, the further apart the two lines become. As the ridge parameter increases, the two lines become increasingly closer together.

# %% [markdown]
# There are other regularizers other than ridge regression, such as LASSO. **Explain** the differences between LASSO and Ridge Regression and how it changes the solution mathematically.
#
# **(TODO: Write here)** In ridge regression the penalty function is the sum of squares of the coefficients, while the penalty function in lasso is the sum of the absolute values of the coefficients. It changes the solution mathematically because lasso tends to make coefficients close to 0 while ridge won't set the value of the coefficient to 0.

# %%
# TODO: Create code for LASSO here
# TODO: Plot your regression line over the input points. 

def LASSO(X, y, ridge=.001):
    return linear_model.Lasso(ridge, X, y)

# TODO: check against training data
theta = LASSO(X_train,Y_train)
thetaTest = LASSO(X_test, Y_test)

# TODO: check against testing data
print(theta)
print(thetaTest)
# plt.plot(theta)
# plt.plot(theta)
# plt.show()
# Out:
# Lasso(alpha=0.001,
#       fit_intercept=array([[6.27451872e+01, 4.24729900e+02, 2.24913998e+03],
#        [1.11108877e+02, 2.23029603e+02, 1.33736577e+03],
#        [4.80704072e+01, 2.20357823e+02, 1.19792993e+03],
#        [3.42213134e+01, 3.63792709e+02, 1.88740617e+03],
#        [3.79084585e+01, 1.43924073e+02, 7.95437280e+02],
#        [1.07100392e+02, 2.54136163e+02, 1.48488160e+03],
#        [6.67523347e+01, 2.73617056e+0...
#        [ 562.2201815],
#        [ 604.4183016],
#        [1195.191579 ],
#        [ 763.4091191],
#        [ 385.2753447],
#        [ 754.751637 ],
#        [ 710.8092285],
#        [ 939.7291678],
#        [ 662.7291893],
#        [ 997.3940158],
#        [ 832.5661404],
#        [ 991.4601294],
#        [ 783.1278436],
#        [ 803.5031171],
#        [ 654.4738147],
#        [ 792.7985658],
#        [ 599.1875225],
#        [ 905.4595695],
#        [ 664.4089468],
#        [ 353.0441742],
#        [ 704.0135316],
#        [ 732.9943188],
#        [ 927.91481  ],
#        [ 667.4013626],
#        [ 775.9010683],
#        [1008.637643 ]]))
# Lasso(alpha=0.001,
#       fit_intercept=array([[7.56654391e+01, 1.98831844e+02, 1.14549020e+03],
#        [1.06074175e+01, 3.04162813e+02, 1.54202900e+03],
#        [6.82917404e+01, 2.28779573e+02, 1.28048145e+03],
#        [7.36062442e+00, 3.31810696e+02, 1.67377483e+03],
#        [1.14767043e+02, 2.40287938e+02, 1.43097388e+03],
#  [5.50710277e+01 3.16626939e+02 1.69327675e+03]
#  [6.82402903e+00 3.09781378e+02 1.56255495e+03]
#  [4.91185153e+01 3.17394119e+02 1.68520763e+03]
#  [4.73738053e+01 2.30338474e+02 1.24643998e+03]
#  [4.44005187e+01 3.83716538e+02 2.00738373e+03]
#  [4.49563760e+01 2.60686100e+02 1.39334325e+03]
#  [5.78025175e+01 9.01227491e+01 5.66218780e+02]
#  [2.31537948e+01 3.16150801e+02 1.62706160e+03]
#  [5.40213296e+01 2.83025789e+02 1.52317160e+03]
#  [1.00259938e+02 3.11680622e+02 1.75892299e+03]
#  [1.19978383e+01 3.14979009e+02 1.59889072e+03]
#  [3.84221459e+01 3.28552847e+02 1.71960853e+03]
#  [7.37102533e+01 3.88829137e+02 2.09156619e+03]], normalize=[[1047.467603 ]
#  [ 779.6093338]
#  [ 584.8110286]
#  [ 837.8061829]
#  [ 410.303636 ]
#  [ 835.0060521]
#  [ 754.828168 ]
#  [ 888.1746756]
#  [ 556.2693463]
#  [ 748.6923747]
#  [ 471.6170514]
#  [ 706.1545392]
#  [ 464.223764 ]
#  [ 785.9820267]
#  [ 790.5657876]
#  [ 693.5066595]
#  [ 727.3549834]
#  [ 522.6589629]
#  [ 887.2889148]
#  [ 957.7342915]
#  [ 514.8229044]
#  [ 535.5671083]
#  [ 737.6220828]
#  [1130.664592 ]
#  [ 885.9951277]
#  [ 724.1082482]
#  [1157.822341 ]
#  [ 876.2271393]
#  [ 802.7477974]
#  [ 870.1487082]
#  [1058.143569 ]
#  [ 801.1873582]
#  [ 893.2220157]
#  [ 371.883514 ]
#  [ 579.4473476]
#  [ 826.1703348]
#  [1024.856346 ]
#  [ 893.3899559]
#  [ 549.472272 ]
#  [ 831.0915256]
#  [ 702.610386 ]
#  [ 915.1408943]
#  [ 417.7458902]
#  [ 327.9271099]
#  [ 627.7728885]
#  [ 942.7729691]
#  [1266.00619  ]
#  [ 924.6070932]
#  [ 614.6743884]
#  [ 777.2599807]
#  [ 841.382047 ]
#  [ 830.8372004]
#  [ 904.8025663]
#  [ 798.2115577]
#  [ 819.3868847]
#  [1027.053106 ]
#  [ 600.3928275]
#  [1036.746804 ]
#  [ 761.6697273]
#  [ 567.4155458]
#  [ 900.2959836]
#  [ 835.5067222]
#  [ 815.4953091]
#  [ 518.7118372]
#  [ 629.153608 ]
#  [ 792.367183 ]
#  [ 727.1869208]
#  [ 726.1709505]
#  [ 631.5630736]
#  [ 983.1444528]
#  [1160.951776 ]
#  [ 985.3671922]
#  [ 746.8897258]
#  [1004.189869 ]
#  [ 562.2201815]
#  [ 604.4183016]
#  [1195.191579 ]
#  [ 763.4091191]
#  [ 385.2753447]
#  [ 754.751637 ]
#  [ 710.8092285]
#  [ 939.7291678]
#  [ 662.7291893]
#  [ 997.3940158]
#  [ 832.5661404]
#  [ 991.4601294]
#  [ 783.1278436]
#  [ 803.5031171]
#  [ 654.4738147]
#  [ 792.7985658]
#  [ 599.1875225]
#  [ 905.4595695]
#  [ 664.4089468]
#  [ 353.0441742]
#  [ 704.0135316]
#  [ 732.9943188]
#  [ 927.91481  ]
#  [ 667.4013626]
#  [ 775.9010683]
#  [1008.637643 ]] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# C:\Users
#  [1.89345514e+01 2.56151033e+02 1.31862437e+03]
#  [1.69805902e+01 2.97800889e+02 1.52296572e+03]], normalize=[[ 631.7097  ]
#  [ 645.044839]
#  [ 667.050781]
#  [ 690.783579]
#  [ 834.792419]
#  [ 565.449218]
#  [ 568.201096]
#  [ 605.447499]
#  [ 862.597122]
#  [ 827.827953]
#  [ 702.205766]
#  [ 913.332135]
#  [ 605.149588]
#  [ 739.907617]
#  [ 755.286333]
#  [ 788.299741]
#  [ 680.503152]
#  [ 734.176848]
#  [ 443.340957]
#  [ 662.233117]
#  [ 944.468117]
#  [ 702.62536 ]
#  [ 552.825471]
#  [ 651.934467]
#  [ 769.477189]
#  [ 626.760788]
#  [ 619.829845]
#  [ 238.524426]
#  [ 518.71404 ]
#  [ 688.160632]
#  [ 584.902096]
#  [ 722.990726]
#  [ 385.5941  ]
#  [ 638.011399]
#  [ 672.394725]
#  [ 640.020447]
#  [1019.12496 ]
#  [ 622.331181]
#  [ 686.456516]
#  [ 628.848748]
#  [1022.12748 ]
#  [ 719.619367]
#  [ 758.908137]
#  [ 785.432917]
#  [ 930.357379]
#  [ 669.191182]
#  [1008.34408 ]
#  [ 793.227927]
#  [1066.79386 ]
#  [ 535.981194]
#  [ 592.572714]
#  [ 797.59726 ]
#  [ 878.494885]
#  [ 693.337684]
#  [ 492.920883]
#  [ 750.926147]
#  [ 772.719743]
#  [ 634.909733]
#  [ 533.705912]
#  [ 816.396772]
#  [ 784.810791]
#  [ 539.33127 ]
#  [ 872.187991]
#  [ 364.129953]
#  [ 729.58676 ]
#  [ 452.240765]
#  [ 771.651293]
#  [ 636.830707]
#  [ 661.042522]
#  [1054.32492 ]
#  [ 555.50745 ]
#  [ 939.423072]
#  [ 744.99426 ]
#  [ 537.039627]
#  [ 896.970566]
#  [ 941.519997]
#  [ 906.718288]
#  [ 900.282705]
#  [ 670.409829]
#  [ 551.593464]
#  [ 784.101815]
#  [ 701.110323]
#  [ 795.958633]
#  [ 593.507554]
#  [ 623.73265 ]
#  [ 767.767172]
#  [ 765.532876]
#  [ 682.029484]
#  [ 607.087713]
#  [ 947.398278]
#  [ 555.463159]
#  [ 623.561396]
#  [ 843.570424]
#  [ 572.078903]
#  [ 773.459393]
#  [ 687.478045]
#  [ 765.430771]
#  [ 578.564968]
#  [ 578.006301]
#  [ 655.403048]] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %% [markdown]
# **Explain** the effect elastic nets had on your values for theta compared to OLS. Also try different values for the ridge parameters and describe how they effect your results.
#
# **(TODO: Write here)**

# %% [markdown]
# **Explain** the differences between LASSO, Ridge Regression and Elastic Nets and how it changes the solution mathematically.
#
# **(TODO: Write here)**

# %%
# TODO: Create code for Elastic Nets here. You can use a library such as scipy
# TODO: Plot your regression line over the input points.
#from sklearn.datasets import make_regression

def EN(X,y):
    return linear_model.ElasticNet(X, y)

# TODO: check against training data
theta = EN(X_train,Y_train)
thetaTest = EN(X_test, Y_test)

# TODO: check against testing data
print(theta)
print(thetaTest)
# plt.plot(theta)
# plt.plot(thetaTest)
# plt.show()
# Out:
# ElasticNet(alpha=array([[6.27451872e+01, 4.24729900e+02, 2.24913998e+03],
#        [1.11108877e+02, 2.23029603e+02, 1.33736577e+03],
#        [4.80704072e+01, 2.20357823e+02, 1.19792993e+03],
#        [3.42213134e+01, 3.63792709e+02, 1.88740617e+03],
#        [3.79084585e+01, 1.43924073e+02, 7.95437280e+02],
#        [1.07100392e+02, 2.54136163e+02, 1.48488160e+03],
#        [6.67523347e+01, 2.73617056e+02, 1.50158995e+0...
#        [ 562.2201815],
#        [ 604.4183016],
#        [1195.191579 ],
#        [ 763.4091191],
#        [ 385.2753447],
#        [ 754.751637 ],
#        [ 710.8092285],
#        [ 939.7291678],
#        [ 662.7291893],
#        [ 997.3940158],
#        [ 832.5661404],
#        [ 991.4601294],
#        [ 783.1278436],
#        [ 803.5031171],
#        [ 654.4738147],
#        [ 792.7985658],
#        [ 599.1875225],
#        [ 905.4595695],
#        [ 664.4089468],
#        [ 353.0441742],
#        [ 704.0135316],
#        [ 732.9943188],
#        [ 927.91481  ],
#        [ 667.4013626],
#        [ 775.9010683],
#        [1008.637643 ]]))
# ElasticNet(alpha=array([[7.56654391e+01, 1.98831844e+02, 1.14549020e+03],
#        [1.06074175e+01, 3.04162813e+02, 1.54202900e+03],
#        [6.82917404e+01, 2.28779573e+02, 1.28048145e+03],
#        [7.36062442e+00, 3.31810696e+02, 1.67377483e+03],
#        [1.14767043e+02, 2.40287938e+02, 1.43097388e+03],
#        [7.46787371e+00, 2.68747459e+02, 1.35867314e+03],
#        [3.75871452e+01, 2.25914156e+02, 1.20474517e+0...
#        [ 537.039627],
#        [ 896.970566],
#        [ 941.519997],
#        [ 906.718288],
#        [ 900.282705],
#        [ 670.409829],
#        [ 551.593464],
#        [ 784.101815],
#        [ 701.110323],
#        [ 795.958633],
#        [ 593.507554],
#        [ 623.73265 ],
#        [ 767.767172],
#        [ 765.532876],
#        [ 682.029484],
#        [ 607.087713],
#        [ 947.398278],
#        [ 555.463159],
#        [ 623.561396],
#        [ 843.570424],
#        [ 572.078903],
#        [ 773.459393],
#        [ 687.478045],
#        [ 765.430771],
#        [ 578.564968],
#        [ 578.006301],
#        [ 655.403048]]))
# C:\Users\alari\miniconda3\envs\fri_rl\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass l1_ratio=[[1047.467603 ]
#  [ 779.6093338]
#  [ 584.8110286]
#  [ 837.8061829]
#  [ 410.303636 ]
#  [ 835.0060521]
#  [ 754.828168 ]
#  [ 888.1746756]
#  [ 556.2693463]
#  [ 748.6923747]
#  [ 471.6170514]
#  [ 706.1545392]
#  [ 464.223764 ]
#  [ 785.9820267]
#  [ 790.5657876]
#  [ 693.5066595]
#  [ 727.3549834]
#  [ 522.6589629]
#  [ 887.2889148]
#  [ 957.7342915]
#  [ 514.8229044]
#  [ 535.5671083]
#  [ 737.6220828]
#  [1130.664592 ]
#  [ 885.9951277]
#  [ 724.1082482]
#  [1157.822341 ]
#  [ 876.2271393]
#  [ 802.7477974]
#  [ 870.1487082]
#  [1058.143569 ]
#  [ 801.1873582]
#  [ 893.2220157]
#  [ 371.883514 ]
#  [ 579.4473476]
#  [ 826.1703348]
#  [1024.856346 ]
#  [ 893.3899559]
#  [ 549.472272 ]
#  [ 831.0915256]
#  [ 702.610386 ]
#  [ 915.1408943]
#  [ 417.7458902]
#  [ 327.9271099]
#  [ 627.7728885]
#  [ 942.7729691]
#  [1266.00619  ]
#  [ 924.6070932]
#  [ 614.6743884]
#  [ 777.2599807]
#  [ 841.382047 ]
#  [ 830.8372004]
#  [ 904.8025663]
#  [ 798.2115577]
#  [ 819.3868847]
#  [1027.053106 ]
#  [ 600.3928275]
#  [1036.746804 ]
#  [ 761.6697273]
#  [ 567.4155458]
#  [ 900.2959836]
#  [ 835.5067222]
#  [ 815.4953091]
#  [ 518.7118372]
#  [ 629.153608 ]
#  [ 792.367183 ]
#  [ 727.1869208]
#  [ 726.1709505]
#  [ 631.5630736]
#  [ 983.1444528]
#  [1160.951776 ]
#  [ 985.3671922]
#  [ 746.8897258]
#  [1004.189869 ]
#  [ 562.2201815]
#  [ 604.4183016]
#  [1195.191579 ]
#  [ 763.4091191]
#  [ 385.2753447]
#  [ 754.751637 ]
#  [ 710.8092285]
#  [ 939.7291678]
#  [ 662.7291893]
#  [ 997.3940158]
#  [ 832.5661404]
#  [ 991.4601294]
#  [ 783.1278436]
#  [ 803.5031171]
#  [ 654.4738147]
#  [ 792.7985658]
#  [ 599.1875225]
#  [ 905.4595695]
#  [ 664.4089468]
#  [ 353.0441742]
#  [ 704.0135316]
#  [ 732.9943188]
#  [ 927.91481  ]
#  [ 667.4013626]
#  [ 775.9010683]
#  [1008.637643 ]] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)
# C:\Users\alari\miniconda3\envs\fri_rl\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning: Pass l1_ratio=[[ 631.7097  ]
#  [ 645.044839]
#  [ 667.050781]
#  [ 690.783579]
#  [ 834.792419]
#  [ 565.449218]
#  [ 568.201096]
#  [ 605.447499]
#  [ 862.597122]
#  [ 827.827953]
#  [ 702.205766]
#  [ 913.332135]
#  [ 605.149588]
#  [ 739.907617]
#  [ 755.286333]
#  [ 788.299741]
#  [ 680.503152]
#  [ 734.176848]
#  [ 443.340957]
#  [ 662.233117]
#  [ 944.468117]
#  [ 702.62536 ]
#  [ 552.825471]
#  [ 651.934467]
#  [ 769.477189]
#  [ 626.760788]
#  [ 619.829845]
#  [ 238.524426]
#  [ 518.71404 ]
#  [ 688.160632]
#  [ 584.902096]
#  [ 722.990726]
#  [ 385.5941  ]
#  [ 638.011399]
#  [ 672.394725]
#  [ 640.020447]
#  [1019.12496 ]
#  [ 622.331181]
#  [ 686.456516]
#  [ 628.848748]
#  [1022.12748 ]
#  [ 719.619367]
#  [ 758.908137]
#  [ 785.432917]
#  [ 930.357379]
#  [ 669.191182]
#  [1008.34408 ]
#  [ 793.227927]
#  [1066.79386 ]
#  [ 535.981194]
#  [ 592.572714]
#  [ 797.59726 ]
#  [ 878.494885]
#  [ 693.337684]
#  [ 492.920883]
#  [ 750.926147]
#  [ 772.719743]
#  [ 634.909733]
#  [ 533.705912]
#  [ 816.396772]
#  [ 784.810791]
#  [ 539.33127 ]
#  [ 872.187991]
#  [ 364.129953]
#  [ 729.58676 ]
#  [ 452.240765]
#  [ 771.651293]
#  [ 636.830707]
#  [ 661.042522]
#  [1054.32492 ]
#  [ 555.50745 ]
#  [ 939.423072]
#  [ 744.99426 ]
#  [ 537.039627]
#  [ 896.970566]
#  [ 941.519997]
#  [ 906.718288]
#  [ 900.282705]
#  [ 670.409829]
#  [ 551.593464]
#  [ 784.101815]
#  [ 701.110323]
#  [ 795.958633]
#  [ 593.507554]
#  [ 623.73265 ]
#  [ 767.767172]
#  [ 765.532876]
#  [ 682.029484]
#  [ 607.087713]
#  [ 947.398278]
#  [ 555.463159]
#  [ 623.561396]
#  [ 843.570424]
#  [ 572.078903]
#  [ 773.459393]
#  [ 687.478045]
#  [ 765.430771]
#  [ 578.564968]
#  [ 578.006301]
#  [ 655.403048]] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   "will result in an error", FutureWarning)

# %% [markdown]
# What is the purpose of a regularizer?
#
# **(TODO: Write here)** The purpose of a regularizer is to prevent overfitting.

# %% [markdown]
# Give two examples where a regularizer would give more robust models.
#
# **(TODO: Write here)**

# %% [markdown]
# Explain with reference to the dataset why a regularizer achieved better performance than OLS.
#
# **(TODO: Write here)**

# %% [markdown]
# <hr class='light-separate' />

# %% [markdown]
# Implement feature transformation to fit a line to the curve generated from the .csv file.

# %%
X = np.genfromtxt('feature_transform.csv', delimiter=',')
y = X[:,2].reshape(500, 1)
X = X[:,:2]

# %%
# TODO: Write the lambda function phi which will transform X
# TODO: Plot the transformation and the resulting line after transforming

phi = "fill in with lambda function"
import matplotlib.pyplot as plt
plt.scatter(X[:,0],y,color=(0.0,0.5,0.0))
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# <hr class='light-separate' />

# %% [markdown]
# Recall what you learned about polynomial regression and explain what is happening to the model as you increase the degrees. Run the cell below and use the slider to help you.
#
# **(TODO: Write here)**

# %%
# DO NOT ALTER

import pandas as pd
import ipywidgets as widgets
from ipywidgets import interact
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

boston = datasets.load_boston()
data = pd.DataFrame(boston.data,columns=boston.feature_names)
data = pd.concat([data,pd.Series(boston.target,name='MEDV')],axis=1)

X = data[['LSTAT']].values
y = data['MEDV']

x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42, shuffle=True)

temp = pd.DataFrame({'x':x_train.reshape(1, 354)[0], 'y':y_train})
temp = temp.sort_values('x')
x_train = temp['x'].values.reshape(354,1)
y_train = temp['y'].values

temp = pd.DataFrame({'x':x_test.reshape(1, 152)[0], 'y':y_test})
temp = temp.sort_values('x')
x_test = temp['x'].values.reshape(152,1)
y_test = temp['y'].values

def f(degree):
    model = make_pipeline(PolynomialFeatures(degree), LinearRegression())
    model.fit(x_train,y_train)
    y_plot = model.predict(x_test)
    
    plt.scatter(x_train, y_train, s=10, color='red', alpha=.3)
    plt.scatter(x_test, y_test, s=10)

    test_sr = (y_test - y_plot)**2
    test_ssr = test_sr.sum()
    test_asr = test_ssr/len(test_sr)
    
    y_plot_train = model.predict(x_train)
    train_sr = (y_train - y_plot_train)**2
    train_ssr = train_sr.sum()
    train_asr = train_ssr/len(train_sr)
    
    plt.plot(x_test, y_plot, label="degree %d" % degree + '; Test Error: %.2f' % test_asr + '; Train Error: %.2f' % train_asr, color='green')
    plt.legend(loc='upper right')
    plt.show()
    
interact(f, degree = widgets.IntSlider(min=1, max=20, step=1, value=1))
# Out:
# <function __main__.f(degree)>
